# %% [markdown]
# # 첫번째
# - 첫번째
#   - 두번째
# ## 두번째
# ### 세번째
# #### 네번째

# %%
code = 1    # 주석입니다(메모하려면 #을 사용)
code
# Out:
# 1

# %%
num = 3
print(num)
# Out:
# 3

# %%
num1 = 13
num1
# Out:
# 13

# %%
num2 = 25
num2
# Out:
# 25

# %%
num3 = 77
num3
# Out:
# 77

# %%
type(num2)
# Out:
# int

# %%
num3 = 3.1425
num3
# Out:
# 3.1425

# %%
num4 = 1.25
num4
# Out:
# 1.25

# %%
num4 = 3.12
num4
# Out:
# 3.12

# %%
type(num3)
# Out:
# float

# %%
str1 = "Funny python"
str1
# Out:
# 'Funny python'

# %%
type(str1)
# Out:
# str

# %%
number = 30
Number = 20
print("number:", number)
print("Number:", Number)
# Out:
# number: 30
# Number: 20

# %%
number_Number = 10
number_Number
# Out:
# 10

# %%
print(number)
print(Number)
# Out:
# 30
# 20

# %%
print("나 오늘" , "너무", "씐나", sep="^^")
# Out:
# 나 오늘^^너무^^씐나

# %%
1a = 10
# Out:
#   Cell In[119], line 1
#     1a = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
sum([1,2])
# Out:
# 3

# %% [markdown]
# #

# %%
sum = 10

# %%
False
None

# %%
# 파이썬 예약어 확인
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
a, b = 10, 15
print(a)
print(b)
# Out:
# 10
# 15

# %%
# 문자열 대입 방법
str1 = str2 = "python"
print(str1)
print(str2)
# Out:
# python
# python

# %%
s = "she's gone"
s
# Out:
# "she's gone"

# %%
x = 100
y = 200
sum1 = x + y
print(sum1)
# Out:
# 300

# %%
s = "여러줄로 구성된 \n문자열을 하나로 대입할 때"
print(s)
# Out:
# 여러줄로 구성된
# 문자열을 하나로 대입할 때

# %%
s = '''여러줄로 구성된
문자열을 하나로
대입할 때'''
print(s)
# Out:
# 여러줄로 구성된
# 문자열을 하나로
# 대입할 때

# %%
s = """여러줄로 구성된
문자열을 하나로
대입할 때"""
print(s)
# Out:
# 여러줄로 구성된
# 문자열을 하나로
# 대입할 때

# %%
s = "오늘은 즐거운 파이썬 \t 수업 시간입니다"
print(s)
# Out:
# 오늘은 즐거운 파이썬 	 수업 시간입니다

# %%
s = "My name is DH"
print(s[0])
print(s[8])
# Out:
# M
# i

# %%
s = "My name is DH"
print(s[-2])
print(s[-1])
# Out:
# D
# H

# %%
s = "My name is DH"
print(s[0:2])
print(s[3:7])
print(s[8:10])
# Out:
# My
# name
# is

# %%
s = "My name is DH"
print(s[0:7])
print(s[:7])
# Out:
# My name
# My name

# %%
s = "My name is DH"
print(s[8:13])
print(s[-5:])
print(s[8:])
# Out:
# is DH
# is DH
# is DH

# %%
s = "My name is DH"
print(s[:])
print(s[:13])
print(s[0:13])
print(s)
# Out:
# My name is DH
# My name is DH
# My name is DH
# My name is DH

# %%
s = "2020년 3월 3일의 날씨는 맑음입니다."
print("날짜 :",s[:11])
print("날씨 :",s[-6:-4])
# Out:
# 날짜 : 2020년 3월 3일
# 날씨 : 맑음

# %%
day = 7
s = "오늘은 7월 %d일 입니다."%day
s
# Out:
# '오늘은 7월 7일 입니다.'

# %%
day = 8
s = "오늘은 7월 %d일 입니다."%day
s
# Out:
# '오늘은 7월 8일 입니다.'

# %%
month = 7
day = 8
s = "오늘은 %d월 %d일 입니다."%(month,day)
s
# Out:
# '오늘은 7월 8일 입니다.'

# %%
month = 7
day = 7
s = "오늘은 {}월 {}일 입니다.".format(month,day)
s
# Out:
# '오늘은 7월 7일 입니다.'

# %%
month = 7
day = 7
s = f"오늘은 {month}월 {day}일 입니다."
s
# Out:
# '오늘은 7월 7일 입니다.'

# %%
x = 100
y = 200
sum2 = x + y
print(f"{x}와 {y}의 합은 {sum2}입니다.")
# Out:
# 100와 200의 합은 300입니다.

# %%
# count 함수
# 문자열에 포함된 문자의 개수 세는 함수
s = "오늘은 파이썬 수업날입니다. 파이썬 너무 재밌네요!"
s.count("수업")
# Out:
# 1

# %%
# find 함수
# 문자열 내의 특정 문자의 위치(index)를 알려주는 함수
s.find("오")
# Out:
# 0

# %%
# '구분자'.join 함수
# 각각의 문자 사이에 구분자를 삽입하여 연결시켜주는 함수
' '.join(["오늘","점심메뉴","추천좀!"])
# Out:
# '오늘 점심메뉴 추천좀!'

# %%
# upper 함수
# 소문자를 대문자로 바꿔주는 함수
s = "I'm Still Hungry"
s.upper()
# Out:
# "I'M STILL HUNGRY"

# %%
# lower 함수
# 대문자를 소문자로 바꿔주는 함수
s = s.lower()

# %%
s
# Out:
# "i'm still hungry"

# %%
# strip 함수
# 양쪽 공백 지우기 함수
s = "          I'm Still Hungry        "
s.strip()
# Out:
# "I'm Still Hungry"

# %%
# replace 함수
# 문자1을 문자2로 바꿔주는 함수
s.replace('Hungry','Happy')
# Out:
# "          I'm Still Happy        "

# %%
# split 함수
# 특정 기준을 통해 좌, 우측으로 문자열을 나눠주는 함수
s = '옆에 공사 현장이 참, 시끄럽네요ㅠ'
s.split('참')
# Out:
# ['옆에 공사 현장이 ', ', 시끄럽네요ㅠ']

# %%
# // = 나머지, % = 나누기(몫)
num1 = 10
num2 = 7

print(num1/num2)
print(num1%num2)
print(num1//num2)
# Out:
# 1.4285714285714286
# 3
# 1

# %%
str1 = "안녕"
str2 = "하세요"

print(str1+ str2)
# Out:
# 안녕하세요

# %%
str1 = "10"
str2 = "7"

print(str1+str2)
# Out:
# 107

# %%
# 문자열과 숫자는 더할수없음
num1 = 10
str2 = "7"

print(num1 + str2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[161], line 5
#       2 num1 = 10
#       3 str2 = "7"
# ----> 5 print(num1 + str2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
num1 = 10
str2 = "7"

print(str(num1) + str2)
print(num1 + int(str2))
# Out:
# 107
# 17

# %%
num1 = 23
num2 = 3
print("더하기결과 :",num1 + num2)
print("빼기 결과 :",num1 - num2)
print("곱하기 결과 :",num1 * num2)
print("나누기 결과 :",num1 / num2)
# Out:
# 더하기결과 : 26
# 빼기 결과 : 20
# 곱하기 결과 : 69
# 나누기 결과 : 7.666666666666667

# %%
num = input("정수를 입력하세요 >> ")
# Out:
# 정수를 입력하세요 >> 23

# %%
num
# Out:
# '23'

# %%
num = int(input("정수를 입력하세요 >> "))
num
# Out:
# 정수를 입력하세요 >> 999
# 999

# %%
num1 = int(input("정수를 입력하세요 >> "))
num2 = int(input("정수를 입력하세요 >> "))

print("더하기결과 :",num1 + num2)
print("빼기 결과 :",num1 - num2)
print("곱하기 결과 :",num1 * num2)
print("나누기 결과 :",num1 / num2)
# Out:
# 정수를 입력하세요 >> 30
# 정수를 입력하세요 >> 30
# 더하기결과 : 60
# 빼기 결과 : 0
# 곱하기 결과 : 900
# 나누기 결과 : 1.0

# %%
py = int(input("Python 점수 입력 >> "))
mi = int(input("머신러닝 점수 입력 >> "))
dl = int(input("딥러닝 점수 입력 >> "))

print("합계 : {}".format(py+mi+dl))
print("평균 : {}".format((py+mi+dl)/3))
# Out:
# Python 점수 입력 >> 80
# 머신러닝 점수 입력 >> 80
# 딥러닝 점수 입력 >> 80
# 합계 : 240
# 평균 : 80.0

# %%
time = int(input("시간 입력 >> "))
hour = time//3600
minute = time%3600//60
second = time%3600%60
print("{}시간 {}분 {}초".format(hour, minute, second))
# Out:
# 시간 입력 >> 9898
# 2시간 44분 58초

# %%
print (s1)

# %%
s = "x"
print(s*10)
# Out:
# xxxxxxxxxx

# %%
y = "안녕하세요"
print (y*2)
# Out:
# 안녕하세요안녕하세요

# %%
print("*"*6,"연산하기","*"*6)
num1 = int(input("정수입력 >> "))
num2 = int(input("정수입력 >> "))
cal = input("+연산자 입력 >> ")
print( "{} {} {} = {}".format(num1,cal,num2,num1+num2))
# Out:
# ****** 연산하기 ******
# 정수입력 >> 10
# 정수입력 >> 20
# +연산자 입력 >> +
# 10 + 20 = 30

# %%
num = int(input("정수 입력 >>"))
power = int(input("지수 입력 >>"))
print("{}의 {}승은 {}입니다.".format(num,power,num**power))
# Out:
# 정수 입력 >>2
# 지수 입력 >>3
# 2의 3승은 8입니다.

# %%
print("-"*7,"구구단","-"*7)
a = int(input("정수 입력 >> "))
b = int(input("정수 입력 >> "))
c = input("*연산자 입력 >> ")
print("{} {} {} = {}".format(a,c,b,a*b))
# Out:
# ------- 구구단 -------
# 정수 입력 >> 9
# 정수 입력 >> 8
# *연산자 입력 >> *
# 9 * 8 = 72

# %%
print("hello world")
# Out:
# hello world

# %%
print("Mary's cosemtics")
# Out:
# Mary's cosemtics

# %%
print('신씨가 소리질렀다."도둑이야"')
# Out:
# 신씨가 소리질렀다."도둑이야"

# %%
print("C:Window")
# Out:
# C:Window

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.")
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
print("오늘은","일요일")
# Out:
# 오늘은 일요일

# %%
print("naver;kakao;sk;samsung")
# Out:
# naver;kakao;sk;samsung

# %%
print("naver","kakao","sk","samsung",sep=";")
# Out:
# naver;kakao;sk;samsung

# %%
print("naver","kakao","sk","samsung",sep="/")
# Out:
# naver/kakao/sk/samsung

# %%
print("first",end=" ");print("second")
# Out:
# first second

# %%
print(5/3)
# Out:
# 1.6666666666666667

# %%
삼성전자 = 50000
총평가금 = 50000 * 10
print(총평가금)
# Out:
# 500000

# %%
시가총액 = 298000000000000
현재가 = 50000
PER = 15.79
print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(PER, type(PER))
# Out:
# 298000000000000 <class 'int'>
# 50000 <class 'int'>
# 15.79 <class 'float'>

# %%
s= "hello"
t= "python"

print(s+"!",t)
# Out:
# hello! python

# %%
a=2
b=3
print(a+a*b)
# Out:
# 8

# %%
a = 132
print(type(a))
# Out:
# <class 'int'>

# %%
num_str = "720"
num_int = int(num_str)
print(num_int, type(num_int))
# Out:
# 720 <class 'int'>

# %%
num = 100
result = str(num)
print(result, type(result))
# Out:
# 100 <class 'str'>

# %%
num = "15.79"
num = float(num)
print(num,type(num))
# Out:
# 15.79 <class 'float'>

# %%
year = "2023"
print(int(year)-3)
print(int(year)-2)
print(int(year)-1)
# Out:
# 2020
# 2021
# 2022

# %%
month = 48584
pay = month * 36
print(pay)
# Out:
# 1749024

# %%
letters = 'python'
print(letters[:1],letters[2:3])
# Out:
# p t

# %%
license_plate = "24가 2210"
print(license_plate[4:])
# Out:
# 2210

# %%
string = '홀짝홀짝홀짝'
print(string[::2])
# Out:
# 홀홀홀

# %%
string = "PYTHON"
print(string[6::-1])
# Out:
# NOHTYP

# %%
phone_number = "010-4503-2184"
phone_number1 = phone_number.replace("-","")
print(phone_number1)
# Out:
# 01045032184

# %%
url = "http://sharebook.kr"
url_split = url.split(".")
print(url_split[-1])
# Out:
# kr

# %%
str1 = 'abc'
str1 = str1.replace('b','B')
print(str1)
# Out:
# aBc

# %%
string = 'abcd'
string = string.replace('b', 'B')
print(string)
# Out:
# aBcd

# %%
sam = 50000
samju = 10
print(sam*samju)
# Out:
# 500000

# %%
a = "132"
print(type(a))
# Out:
# <class 'str'>

# %%
num = "750"
num1 = int(num)
print(num,type(num1))
# Out:
# 750 <class 'int'>

# %%
num = 750
num1 = str(num)상장주식수 = "5,969,782,550"
컴마제거 = 상장주식수.replace(",", "")
타입변환 = int(컴마제거)
print(타입변환, type(타입변환))
print(num,type(num1))
# Out:
# 750 <class 'str'>

# %%
상장주식수 = "5,969,782,550"
컴마제거 = 상장주식수.replace(",", "")
타입변환 = int(컴마제거)
print(타입변환, type(타입변환))
# Out:
# 5969782550 <class 'int'>

# %%
ticker = "btc_krw"
ticker.split("_")
# Out:
# ['btc', 'krw']

# %%
a = "hello world"
a.split()
# Out:
# ['hello', 'world']

# %%
file_name = "2020_보고서.xlsx"
file_name.startswith("2020")
# Out:
# True

# %%
date = "2020-05-01"
date.split("-")
# Out:
# ['2020', '05', '01']

# %%
data = "039490     "
data = data.rstrip()
