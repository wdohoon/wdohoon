# %%
# 대입 연산자 num=num+3 (num+=3)
num = 27
num += 3
num
# Out:
# 30

# %%
num = 100

num -= 55
num
# Out:
# 45

# %%
num = 27

num += 3
num += 3
num += 3
num
# Out:
# 36

# %%
num = 100

num /= 2
num /= 2
num
# Out:
# 25.0

# %%
a = 3
b = 7

print(a > b)
print(a <= b)
print(a == b)
print(a != b)
# Out:
# False
# True
# False
# True

# %%
import random

# %%
a = random.randint(1,10)
b = random.randint(1,10)
print("a:{}, b:{}".format(a,b))

print(a < b)
print(a > b)
print(a == b)
print(a != b)
# Out:
# a:8, b:3
# False
# True
# False
# True

# %%
a = 3
b = 7
not a < b
# Out:
# False

# %%
not a == b
# Out:
# True

# %%
3 > 5 and 10 == 20
# Out:
# False

# %%
3 > 5 and 10 < 20
# Out:
# False

# %%
3 < 5 and 10 < 20
# Out:
# True

# %%
3 > 5 or 10 == 20
# Out:
# False

# %%
3 > 5 or 10 < 20
# Out:
# True

# %%
3 < 5 or 10 < 20
# Out:
# True

# %%
score = 80
"합격" if score >= 60 else "불합격"
# Out:
# '합격'

# %%
socre = 50
"합격" if score >= 60 else "불합격"
# Out:
# '합격'

# %%
score = 50
"합격" if score >= 60 else "불합격"
# Out:
# '불합격'

# %%
a = int(input("정수입력 >>"))
b = int(input("정수입력 >>"))

print("a:{}".format(a)) if a >= b else print("b:{}".format(b))
# Out:
# 정수입력 >>1
# 정수입력 >>1
# a:1

# %%
a = int(input("정수입력 >>"))
b = int(input("정수입력 >>"))

print("b:",b) if b > a else print("a:",a)
# Out:
# 정수입력 >>1
# 정수입력 >>1
# a: 1

# %%
a = int(input("첫 번째 정수 입력 >>"))
b = int(input("두 번째 정수 입력 >>"))
print("두 수의 차 : ", a-b) if a > b else print("두 수의 차 : ", b-a)
# Out:
# 첫 번째 정수 입력 >>1
# 두 번째 정수 입력 >>1
# 두 수의 차 :  0

# %%
a = int(input("정수 입력 >>"))

print("{}는 {}입니다.".format(a,b)) if else print()
# Out:
#   Cell In[126], line 3
#     print("{}는 {}입니다.".format(a,b)) if else print()
#                                        ^
# SyntaxError: invalid syntax

# %%
a = int(input("정수 입력 >>"))

print(f"{a}는 짝수입니다. ") if a%2==0 else print(f"{a}는 홀수입니다. ")
# Out:
# 정수 입력 >>1
# 1는 홀수입니다.

# %%
a = int(input("정수 입력 >>"))

print(f"{a}는 홀수입니다. ") if a%2==1 else print(f"{a}는 짝수입니다. ")
# Out:
# 정수 입력 >>1
# 1는 홀수입니다.

# %%
if True :
    print("실행문장 실행")
print("if문 밖에 있는 실행문장")
# Out:
# 실행문장 실행
# if문 밖에 있는 실행문장

# %%
if False:
    print("실행문장 실행")
print("if문 밖에 있는 실행문장")
# Out:
# if문 밖에 있는 실행문장

# %%
money = 11000

if money >= 10000 : 
    print("택시를 탄다")
# Out:
# 택시를 탄다

# %%
if True : 
    print("실행문장1")
else:
    print("실행문장2")
# Out:
# 실행문장1

# %%
if False:
    print("실행문장1")
else:
    print("실행문장2")
# Out:
# 실행문장2

# %%
money = 11000

if money >= 10000 :
    print("택시를 탄다")
else : 
    print("버스를 탄다")
# Out:
# 택시를 탄다

# %%
money = 9000

if money < 10000:
    print("버스를 탄다")
# Out:
# 버스를 탄다

# %%
num = int(input("정수 입력 >>"))

if num%3==0 and num%5==0:
    print("3과 5의 배수입니다.")
else :
    print("3과 5의 배수가 아닙니다.")
# Out:
# 정수 입력 >>1
# 3과 5의 배수가 아닙니다.

# %%
num = int(input("주민등록번호 뒷자리 입력 >>"))

if num:
    print("당신은 남자입니다 ^^7")
else:
    print("당신은 여자입니다 ^^*")
# Out:
# 주민등록번호 뒷자리 입력 >>1
# 당신은 남자입니다 ^^7

# %%
number = input("주민등록번호 뒷자리 입력 >>")

if number[0] == "1" or number[0] == "3" :
    print("당신은 남자입니다.")
else :
    print("당신은 여자입니다.")
# Out:
# 주민등록번호 뒷자리 입력 >>1
# 당신은 남자입니다.

# %%
number = int(input("주민번호 뒷자리 >>"))

if number//1000000 == 1 or number//1000000 == 3 :
    print("당신은 남자")
else :
    print("당신은 여자")
# Out:
# 주민번호 뒷자리 >>1111111
# 당신은 남자

# %%
a = input("이름 입력 >>")
b = int(input("나이 입력 >>"))
c = input("소지, 미소지 >>")

if b > 20 and c == "소지":
    print(" {} 님은 입장료 24500원에 예약되셨습니다.".format(a))
if b < 19 and c == "소지":
    print(" {} 님은 입장료 26500원에 예약되셨습니다.".format(a))
if b < 20 and c == "미소지":
    print(" {} 님은 입장료 15750원에 예약되셨습니다.".format(a))    
else :
    print(" {} 님은 입장료 35000원에 예약되셨습니다.".format(a))
# Out:
# 이름 입력 >>22
# 나이 입력 >>20
# 소지, 미소지 >>소지
#  22 님은 입장료 35000원에 예약되셨습니다.

# %%
# 놀이동산 입장 예약 프로그램 만들기!
name = input("이름 입력 >>")
age = int(input("나이 입력 >>"))
card = input("카드 소지 여부(소지,미소지) >>")
fee = 35000

#성인일 경우
if age >= 19 :
    # 성인이면서 카드를 소지했을 경우
    fee = fee
    # 성인이면서 카드를 소지했을 경우
    if card == "소지" : 
        fee *= 0.7  # fee = fee * 0.7
# 미성년일 경우
else : 
    # 미성년이면서 카드를 미소지했을 경우
    fee *= 0.5
    # 미성년이면서 카드를 소지했을 경우
    if card == "소지" :
        fee *= 0.9
        
print(f"{name}님은 입장료 {int(fee)}원에 예약되셨습니다.")
# Out:
# 이름 입력 >>도훈
# 나이 입력 >>26
# 카드 소지 여부(소지,미소지) >>소지
# 도훈님은 입장료 24500원에 예약되셨습니다.

# %%
countOFMask = int(input("마스크 개수 입력 >>"))
a = countOFMask*0.8
b = countOFMask*0.5

if countOFMask :
    print("8개들이 포장지 개수 :{}".format(a))
    if countOFMask :
        print("5개들이 포장지 개수 : {}".format(b))
else :
    print(t)
# Out:
# 마스크 개수 입력 >>17
# 8개들이 포장지 개수 :13.600000000000001
# 5개들이 포장지 개수 : 8.5

# %%
#마스크 포장지 계산 문제
countOFMask = int(input("마스크 개수 입력 >>"))

if countOFMask >= 8 :
    eight = countOFMask // 8
    if countOFMask % 8 % 5 == 0 :
        five = countOFMask % 8 // 5
    else :
        five = countOFMask % 8 // 5 + 1
else : 
    eight = 0
    # 마스크가 5개 초과이고 8개 미만일 경우(마스크가 6개, 7개 경우)
    if countOFMask // 5 == 1 :
        five = countOFMask // 5 + 1
    #마스크가 5개 이하일 경우
    else : 
        five = 1
        
print(f"8개들이 포장지 개수 : {eight}")
print(f"5개들이 포장지 개수 : {five}")
# Out:
# 마스크 개수 입력 >>5
# 8개들이 포장지 개수 : 0
# 5개들이 포장지 개수 : 2

# %%
# 간결한 코드
countOFMask = int(input("마스크 개수 입력 >>"))

eight = countOFMask // 8

if countOFMask % 8 > 5 :
    five = countOFMask % 8 // 5 + 1
else : 
    five = 1

print(f"8개들이 포장지 개수 : {eight}")
print(f"5개들이 포장지 개수 : {five}")
# Out:
# 마스크 개수 입력 >>8
# 8개들이 포장지 개수 : 1
# 5개들이 포장지 개수 : 1

# %%
if True :
    print("실행문장1")
elif True :
    print("실행문장2")
# Out:
# 실행문장1

# %%
if False :
    print("실행문장1")
elif True :
    print("실행문장2")
# Out:
# 실행문장2

# %%
num1 = int(input("첫 번째 정수 입력 >>"))
num2 = int(input("두 번째 정수 입력 >>"))

if num1 > num2 :
    print("첫 번째 정수가 더 큽니다.")
elif num2 > num2: 
    print("두 번째 정수가 더 큽니다.")
else :
    print("두 수가 똑같습니다.")
# Out:
# 첫 번째 정수 입력 >>7
# 두 번째 정수 입력 >>7
# 두 수가 똑같습니다.

# %%
# 학점 계산기
score = int(input("점수 입력 >>"))

if score >= 90 :
    print("{}점은 {}학점 입니다.")
elif score >= 80:
    print("{}점은 {}학점 입니다.")
elif socre >= 70 :
    print("{}점은 {}학점 입니다.")
elif score >= 60 :
    print("{}점은 {}학점 입니다.")
else :
    print("{}점은 {}학점 입니다.")
# Out:
# 점수 입력 >>99
# {}점은 {}학점 입니다.

# %%
# 학점 계산기
score = int(input("점수 입력 >>"))

if score >= 90 :
    grade = "A"
elif score >= 80 :
    grade = "B"
elif score >= 70 :
    grade = "C"
elif score >= 60 :
    grade = "D"
else :
    grade = "F"
print(f"{score}은 {grade}학점 입니다.")
# Out:
# 점수 입력 >>55
# 55은 F학점 입니다.

# %%
countOfMask = int(input("마스크 개수 입력 >> "))

mask8 = countOfMask//8
mask5 = countOfMask%8//5

if countOfMask%8%5>=1:
    mask5+=1

print(f"8개들이 포장지 개수 : {mask8}")
print(f"5개들이 포장지 개수 : {mask5}")
# Out:
# 마스크 개수 입력 >> 5
# 8개들이 포장지 개수 : 0
# 5개들이 포장지 개수 : 1

# %%
#사분면 계산
x = int(input("x값을 입력하세요 :"))
y = int(input("y값을 입력하세요 :"))

if x > 0 and y > 0 :
    num = 1
elif x < 0 and y > 0 :
    num = 2
elif x < 0 and y < 0 :
    num = 3
else :
    num = 4
    
print(f"좌표{x},{y}는 {num}사분면 입니다,")
# Out:
# x값을 입력하세요 :-12
# y값을 입력하세요 :5
# 좌표-12,5는 2사분면 입니다,

# %%
age = int(input("나이 입력 >>"))
fee = 1500

if age > 5 :
    num = 750
elif age < 20 :
    num = 1125
elif age > 65 :
    num = 375
else :
    num = 1500
    
print(f"요금은 {num}원 입니다")
# Out:
# 나이 입력 >>15
# 요금은 750원 입니다

# %%
# 버스 요금 계산기 만들기!
age = int(input("나이입력 >>"))
fee = 1500

if age < 5 :
    fee *= 0.5
# 5살 이상 20살 미만
elif age < 20 :
    fee *= 0.75
elif age > 65 :
    fee *= 0.25

print(f"요금은 {int(fee)}원 입니다.")
# Out:
# 나이입력 >>66
# 요금은 375원 입니다.

# %%
insert_coin = int(input("insert coin >>"))
menu = input("메뉴 선택 >>")
drink = ('1.콜라','2.사이다','3.물')

if insert_coin < 600:
    print("잔액 부족")
elif menu in not drink :
    print('잘못된 메뉴')
elif insert_coin < 600:
    print("금액 부족")


    
money = insert_coin
price = insert_coin

change = money - price
change_1000 = change // 1000
change_500 = (change % 1000) // 500
change_100 = (change % 500) // 100


print(f"""
=====================================
=======---- 자판기 ----==============
=====================================
==1.콜라==2.사이다==3.물====insert===
==------==--------==-----===------===
==  600  ==  800 === 1000 == 000원===
=============================-----===
=====================================
==+++++++++++++++++++++++++++++++++==
==+++++++++++++++++++++++++++++++++==
==+++++++++++++++++++++++++++++++++==
==+++++++++++               +++++++==
==+++++++++++    SMHRD      +++++++==
==+++++++++++               +++++++==
==+++++++++++++++++++++++++++++++++==
==+++++++++++++++++++++++++++++++++==
=====================================
=====================================
  ===                          ===
  ===                          ===
잔돈 >> 1000원{change_1000}개, 500원{change_500}개, 100원{change_100}개""")
# Out:
#   Cell In[383], line 7
#     elif menu in not drink :
#                  ^
# SyntaxError: invalid syntax
