# %% [markdown]
# <a href="https://colab.research.google.com/github/wdohoon/wdohoon/blob/main/ex07)_%EB%94%A5%EB%9F%AC%EB%8B%9D_%ED%8C%A8%EC%85%98%EC%9D%B4%EB%AF%B8%EC%A7%80_%EC%9D%B4%EC%A7%84%EB%B6%84%EB%A5%98(%ED%99%9C%EC%84%B1%ED%99%94_%EC%B5%9C%EC%A0%81%ED%99%94_%EB%B3%80%EA%B2%BD).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 목표
# - 10종류의 패션 이미지 데이터를 분류하는 신경망 모델을 만들어보자!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# keras에서 지원하는 패션 이미지 데이터 임포트
from tensorflow.keras.datasets import fashion_mnist

# %%
data = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
(X_train, y_train), (X_test, y_test) = data

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
y_train_onehot = pd.get_dummies(y_train)
y_test_onehot = pd.get_dummies(y_test)

y_train_onehot.shape, y_test_onehot.shape
# Out:
# ((60000, 10), (10000, 10))

# %% [markdown]
# ### 활성화함수, 최적화함수 별 비교
# 1. 중간층 활성화함수 : sigmoid, 최적화함수 : SGD
# 2. 중간층 활성화함수 : relu, 최적화함수 : SGD
# 3. 중간층 활성화함수 : relu, 최적화함수 : Adam
# - 각각의 신경망을 설계하고 결과를 비교해보세요~!

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %% [markdown]
# - sigmoid, SGD

# %%
model1 = Sequential()

model1.add(Flatten(input_shape=(28,28))) # 입력층
model1.add(Dense(500, activation='sigmoid')) # 중간층들
model1.add(Dense(300, activation='sigmoid'))
model1.add(Dense(100, activation='sigmoid'))
model1.add(Dense(30, activation='sigmoid'))
model1.add(Dense(10, activation='softmax')) # 출력층

model1.compile(loss='categorical_crossentropy', optimizer='SGD', metrics=['acc'])

# %% [markdown]
# - relu, SGD

# %%
model2 = Sequential()

model2.add(Flatten(input_shape=(28,28))) # 입력층
model2.add(Dense(500, activation='relu')) # 중간층들
model2.add(Dense(300, activation='relu'))
model2.add(Dense(100, activation='relu'))
model2.add(Dense(30, activation='relu'))
model2.add(Dense(10, activation='softmax')) # 출력층

model2.compile(loss='categorical_crossentropy', optimizer='SGD', metrics=['acc'])

# %% [markdown]
# - relu, Adam

# %%
model3 = Sequential()

model3.add(Flatten(input_shape=(28,28))) # 입력층
model3.add(Dense(500, activation='relu')) # 중간층들
model3.add(Dense(300, activation='relu'))
model3.add(Dense(100, activation='relu'))
model3.add(Dense(30, activation='relu'))
model3.add(Dense(10, activation='softmax')) # 출력층

model3.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['acc'])

# %%
h1 = model1.fit(X_train, y_train_onehot, epochs=30,
              batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/30
# 375/375 [==============================] - 7s 5ms/step - loss: 2.3140 - acc: 0.1396 - val_loss: 2.2852 - val_acc: 0.1659
# Epoch 2/30
# 375/375 [==============================] - 2s 6ms/step - loss: 2.2769 - acc: 0.3245 - val_loss: 2.2680 - val_acc: 0.4246
# Epoch 3/30
# 375/375 [==============================] - 2s 4ms/step - loss: 2.2575 - acc: 0.4018 - val_loss: 2.2449 - val_acc: 0.4283
# Epoch 4/30
# 375/375 [==============================] - 1s 4ms/step - loss: 2.2287 - acc: 0.4146 - val_loss: 2.2087 - val_acc: 0.4330
# Epoch 5/30
# 375/375 [==============================] - 1s 4ms/step - loss: 2.1813 - acc: 0.3673 - val_loss: 2.1471 - val_acc: 0.3615
# Epoch 6/30
30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2748 - acc: 0.8978 - val_loss: 0.3472 - val_acc: 0.8797
# Epoch 17/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2633 - acc: 0.9009 - val_loss: 0.3481 - val_acc: 0.8777
# Epoch 18/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2625 - acc: 0.9011 - val_loss: 0.3413 - val_acc: 0.8783
# Epoch 19/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2643 - acc: 0.9016 - val_loss: 0.3410 - val_acc: 0.8828
# Epoch 20/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2497 - acc: 0.9055 - val_loss: 0.3653 - val_acc: 0.8798
# Epoch 21/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2497 - acc: 0.9069 - val_loss: 0.3498 - val_acc: 0.8816
# Epoch 22/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2486 - acc: 0.9073 - val_loss: 0.3892 - val_acc: 0.8692
# Epoch 23/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2441 - acc: 0.9080 - val_loss: 0.3542 - val_acc: 0.8780
# Epoch 24/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2384 - acc: 0.9100 - val_loss: 0.3532 - val_acc: 0.8813
# Epoch 25/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2259 - acc: 0.9142 - val_loss: 0.3744 - val_acc: 0.8800
# Epoch 26/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2253 - acc: 0.9150 - val_loss: 0.3706 - val_acc: 0.8820
# Epoch 27/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2257 - acc: 0.9144 - val_loss: 0.3684 - val_acc: 0.8777
# Epoch 28/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2173 - acc: 0.9187 - val_loss: 0.3550 - val_acc: 0.8878
# Epoch 29/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2152 - acc: 0.9195 - val_loss: 0.3511 - val_acc: 0.8748
# Epoch 30/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2139 - acc: 0.9193 - val_loss: 0.3673 - val_acc: 0.8808

# %%
plt.figure(figsize=(15,5))

# sigmoid, SGD 사용한 모델
plt.plot(h1.history['acc'], label='acc1')
plt.plot(h1.history['val_acc'], label='val_acc1')

# relu, SGD 사용한 모델
plt.plot(h2.history['acc'], label='acc2')
plt.plot(h2.history['val_acc'], label='val_acc2')

# relu, Adam 사용한 모델
plt.plot(h3.history['acc'], label='acc3')
plt.plot(h3.history['val_acc'], label='val_acc3')

plt.legend()
plt.show()

# %%
# SGD의 학습률(learning rate)을 줄여서 좀 더 안정적이고 정확하게 학습시켜보자
from tensorflow.keras.optimizers import SGD

# %%
model4 = Sequential()

model4.add(Flatten(input_shape=(28,28))) # 입력층
model4.add(Dense(500, activation='relu')) # 중간층들
model4.add(Dense(300, activation='relu'))
model4.add(Dense(100, activation='relu'))
model4.add(Dense(30, activation='relu'))
model4.add(Dense(10, activation='softmax')) # 출력층

# optimizer에 문자열로 'SGD'가 아닌, 함수로써 SGD() 작성
model4.compile(loss='categorical_crossentropy',
               optimizer=SGD(learning_rate=0.001), # SGD의 lr 디폴트값 : 0.01
               metrics=['acc'])

h4 = model4.fit(X_train, y_train_onehot, epochs=30,
              batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/30
# 375/375 [==============================] - 3s 7ms/step - loss: 4.5113 - acc: 0.4479 - val_loss: 1.3716 - val_acc: 0.5107
# Epoch 2/30
# 375/375 [==============================] - 1s 4ms/step - loss: 1.3115 - acc: 0.5579 - val_loss: 1.2768 - val_acc: 0.5963
# Epoch 3/30
# 375/375 [==============================] - 2s 4ms/step - loss: 1.2183 - acc: 0.6218 - val_loss: 1.2121 - val_acc: 0.6299
# Epoch 4/30
# 375/375 [==============================] - 1s 4ms/step - loss: 1.1603 - acc: 0.6383 - val_loss: 1.1901 - val_acc: 0.6265
# Epoch 5/30
# 375/375 [==============================] - 1s 4ms/step - loss: 1.1114 - acc: 0.6459 - val_loss: 1.1206 - val_acc: 0.6458
# Epoch 6/30
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0696 - acc: 0.6522 - val_loss: 1.0924 - val_acc: 0.6488
# Epoch 7/30
# 375/375 [==============================] - 1s 4ms/step - loss: 1.0192 - acc: 0.6586 - val_loss: 1.0259 - val_acc: 0.6575
# Epoch 8/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.9528 - acc: 0.6706 - val_loss: 0.9790 - val_acc: 0.6688
# Epoch 9/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9185 - acc: 0.6917 - val_loss: 0.9454 - val_acc: 0.6890
# Epoch 10/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.8930 - acc: 0.7053 - val_loss: 0.9294 - val_acc: 0.7046
# Epoch 11/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.8568 - acc: 0.7238 - val_loss: 0.8438 - val_acc: 0.7587
# Epoch 12/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.7548 - acc: 0.7793 - val_loss: 0.7838 - val_acc: 0.7742
# Epoch 13/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.7142 - acc: 0.7950 - val_loss: 0.7431 - val_acc: 0.7931
# Epoch 14/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.6909 - acc: 0.8020 - val_loss: 0.7264 - val_acc: 0.7974
# Epoch 15/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.6713 - acc: 0.8070 - val_loss: 0.7249 - val_acc: 0.7979
# Epoch 16/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.6537 - acc: 0.8132 - val_loss: 0.7272 - val_acc: 0.7993
# Epoch 17/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.6383 - acc: 0.8201 - val_loss: 0.7112 - val_acc: 0.7956
# Epoch 18/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.6205 - acc: 0.8343 - val_loss: 0.6799 - val_acc: 0.8278
# Epoch 19/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.6048 - acc: 0.8410 - val_loss: 0.6747 - val_acc: 0.8227
# Epoch 20/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.5870 - acc: 0.8454 - val_loss: 0.6447 - val_acc: 0.8279
# Epoch 21/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.5714 - acc: 0.8464 - val_loss: 0.6365 - val_acc: 0.8304
# Epoch 22/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.5561 - acc: 0.8473 - val_loss: 0.6340 - val_acc: 0.8258
# Epoch 23/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.5370 - acc: 0.8377 - val_loss: 0.5968 - val_acc: 0.7908
# Epoch 24/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.5009 - acc: 0.8149 - val_loss: 0.5551 - val_acc: 0.7961
# Epoch 25/30
# 375/375 [==============================] - 2s 4ms/step - loss: 0.4718 - acc: 0.8368 - val_loss: 0.5426 - val_acc: 0.8367
# Epoch 26/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4447 - acc: 0.8522 - val_loss: 0.5095 - val_acc: 0.8378
# Epoch 27/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4216 - acc: 0.8570 - val_loss: 0.5062 - val_acc: 0.8382
# Epoch 28/30
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4071 - acc: 0.8605 - val_loss: 0.4916 - val_acc: 0.8426
# Epoch 29/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3928 - acc: 0.8649 - val_loss: 0.4793 - val_acc: 0.8413
# Epoch 30/30
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3816 - acc: 0.8682 - val_loss: 0.4701 - val_acc: 0.8475

# %%
plt.figure(figsize=(15,5))

# sigmoid, SGD 사용한 모델
plt.plot(h1.history['acc'], label='acc1')
plt.plot(h1.history['val_acc'], label='val_acc1')

# relu, SGD 사용한 모델
plt.plot(h2.history['acc'], label='acc2')
plt.plot(h2.history['val_acc'], label='val_acc2')

# relu, Adam 사용한 모델
plt.plot(h3.history['acc'], label='acc3')
plt.plot(h3.history['val_acc'], label='val_acc3')

# relu, SGD 에서 lr=0.001로 사용한 모델
plt.plot(h4.history['acc'], label='acc4')
plt.plot(h4.history['val_acc'], label='val_acc4')

plt.legend()
plt.show()

# %% [markdown]
# ## 최적화 모델 찾기
# - 모델체크포인트(ModelCheckpoint) : 모델 저장
# - 얼리스탐핑(EarlyStopping) : 조기학습 중단(과대적합, 시간낭비 방지)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# 1. 모델 저장
# 저장 경로 및 파일명 형태 설정
save_path = '/content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_{epoch:03d}_{val_acc:.4f}.hdf5'
# d : 10진수 형태, 03 -> 0이 3개 붙어있는 형태의 자리수 (001, 002, 003, ...)
# f : 소수점 형태, .4 -> 소수점 4자리까지 형태의 자리수 (0.0001, 0.0002, 0.0003, ...)
# hdf5 : 저장되는 모델의 파일의 확장자

f_mckp = ModelCheckpoint(filepath = save_path,  # 파일 경로
                         monitor = 'val_acc',   # 해당 값을 기준으로 파일을 저장할지 결정
                         save_best_only = True, # monitor값이 가장 최고점 혹은 최저점을 갱신했을 경우 모델을 저장
                         mode = 'max',          # save_best_only가 True일 경우 갱신 값의 최대,최소를 결정(디폴드가 max)
                         verbose = 1            # 모델 개선 및 저장 메시지를 출력
                         )

# %%
# 2. 학습 조기 중단
f_early = EarlyStopping(monitor = 'val_acc',
                        patience = 5 # monitor의 값 개선을 몇 번이나 기다려줄지를 결정
                        )

# -> 모델 학습 시 val_acc가 5번의 epoch를 돌 동안 개선되지 않으면 학습을 중단시켜주세요~!

# %%
model5 = Sequential()

model5.add(Flatten(input_shape=(28,28))) # 입력층
model5.add(Dense(500, activation='relu')) # 중간층들
model5.add(Dense(300, activation='relu'))
model5.add(Dense(100, activation='relu'))
model5.add(Dense(30, activation='relu'))
model5.add(Dense(10, activation='softmax')) # 출력층

model5.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['acc'])

h5 = model5.fit(X_train, y_train_onehot, epochs=30,
              batch_size=128, validation_split=0.2,
              callbacks = [f_mckp, f_early])
# Out:
# Epoch 1/30
# 373/375 [============================>.] - ETA: 0s - loss: 1.9544 - acc: 0.6972
# Epoch 1: val_acc improved from 0.47408 to 0.74892, saving model to /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_001_0.7489.hdf5
# 375/375 [==============================] - 4s 5ms/step - loss: 1.9491 - acc: 0.6976 - val_loss: 0.7544 - val_acc: 0.7489
# Epoch 2/30
# 375/375 [==============================] - ETA: 0s - loss: 0.6684 - acc: 0.7907
# Epoch 2: val_acc improved from 0.74892 to 0.80642, saving model to /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_002_0.8064.hdf5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.6684 - acc: 0.7907 - val_loss: 0.6547 - val_acc: 0.8064
# Epoch 3/30
# 370/375 [============================>.] - ETA: 0s - loss: 0.5517 - acc: 0.8226
# Epoch 3: val_acc improved from 0.80642 to 0.82875, saving model to /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_003_0.8288.hdf5
# 375/375 [==============================] - 2s 6ms/step - loss: 0.5514 - acc: 0.8225 - val_loss: 0.5357 - val_acc: 0.8288
# Epoch 4/30
# 372/375 [============================>.] - ETA: 0s - loss: 0.4763 - acc: 0.8440
# Epoch 4: val_acc improved from 0.82875 to 0.84608, saving model to /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_004_0.8461.hdf5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4757 - acc: 0.8442 - val_loss: 0.4642 - val_acc: 0.8461
# Epoch 5/30
# 360/375 [===========================>..] - ETA: 0s - loss: 0.4254 - acc: 0.8592
# Epoch 5: val_acc improved from 0.84608 to 0.85675, saving model to /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_005_0.8568.hdf5
# 375/375 [==============================] - 2s 4ms/step - loss: 0.4242 - acc: 0.8598 - val_loss: 0.4325 - val_acc: 0.8568
# Epoch 6/30
# 373/375 [============================>.] - ETA: 0s - loss: 0.3830 - acc: 0.8679
# Epoch 6: val_acc improved from 0.85675 to 0.85942, saving model to /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_006_0.8594.hdf5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3827 - acc: 0.8680 - val_loss: 0.4345 - val_acc: 0.8594
# Epoch 7/30
# 363/375 [============================>.] - ETA: 0s - loss: 0.3568 - acc: 0.8739
# Epoch 7: val_acc improved from 0.85942 to 0.86075, saving model to /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_007_0.8608.hdf5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3564 - acc: 0.8741 - val_loss: 0.3991 - val_acc: 0.8608
# Epoch 8/30
# 374/375 [============================>.] - ETA: 0s - loss: 0.3340 - acc: 0.8812
# Epoch 8: val_acc improved from 0.86075 to 0.86767, saving model to /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_008_0.8677.hdf5
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3338 - acc: 0.8814 - val_loss: 0.3808 - val_acc: 0.8677
# Epoch 9/30
# 374/375 [============================>.] - ETA: 0s - loss: 0.3182 - acc: 0.8852
# Epoch 9: val_acc improved from 0.86767 to 0.86967, saving model to /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_009_0.8697.hdf5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3180 - acc: 0.8853 - val_loss: 0.3766 - val_acc: 0.8697
# Epoch 10/30
# 372/375 [============================>.] - ETA: 0s - loss: 0.2994 - acc: 0.8916
# Epoch 10: val_acc improved from 0.86967 to 0.87133, saving model to /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_010_0.8713.hdf5
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2992 - acc: 0.8917 - val_loss: 0.3735 - val_acc: 0.8713
# Epoch 11/30
# 372/375 [============================>.] - ETA: 0s - loss: 0.2964 - acc: 0.8914
# Epoch 11: val_acc improved from 0.87133 to 0.88167, saving model to /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_011_0.8817.hdf5
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2968 - acc: 0.8913 - val_loss: 0.3591 - val_acc: 0.8817
# Epoch 12/30
# 361/375 [===========================>..] - ETA: 0s - loss: 0.2869 - acc: 0.8949
# Epoch 12: val_acc did not improve from 0.88167
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2866 - acc: 0.8950 - val_loss: 0.3764 - val_acc: 0.8749
# Epoch 13/30
# 367/375 [============================>.] - ETA: 0s - loss: 0.2851 - acc: 0.8961
# Epoch 13: val_acc did not improve from 0.88167
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2857 - acc: 0.8959 - val_loss: 0.3616 - val_acc: 0.8777
# Epoch 14/30
# 371/375 [============================>.] - ETA: 0s - loss: 0.2838 - acc: 0.8952
# Epoch 14: val_acc did not improve from 0.88167
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2838 - acc: 0.8952 - val_loss: 0.3457 - val_acc: 0.8801
# Epoch 15/30
# 363/375 [============================>.] - ETA: 0s - loss: 0.2690 - acc: 0.9006
# Epoch 15: val_acc did not improve from 0.88167
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2694 - acc: 0.9006 - val_loss: 0.3553 - val_acc: 0.8758
# Epoch 16/30
# 371/375 [============================>.] - ETA: 0s - loss: 0.2679 - acc: 0.9009
# Epoch 16: val_acc did not improve from 0.88167
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2679 - acc: 0.9010 - val_loss: 0.3837 - val_acc: 0.8752

# %% [markdown]
# - 저장된 모델 로드하기

# %%
from tensorflow.keras.models import load_model

# %%
best_model = load_model('/content/drive/MyDrive/Colab Notebooks/SW캠프 데이터 비즈니스 과정/model/FashionModel_011_0.8817.hdf5')

# %%
best_model.evaluate(X_test, y_test_onehot)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3757 - acc: 0.8723
# [0.37570905685424805, 0.8723000288009644]
